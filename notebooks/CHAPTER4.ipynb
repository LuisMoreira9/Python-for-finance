# %% [markdown]
# # <center>CHAPTER 4</center>

# %% [markdown]
# This chapter focuses on NumPy, coovering the following data structures:
#
# ndarray (regular) - n-dimensional array object used for large arrays of numerical data
#
# ndarray (record) - 2-dimensional array object used for tabular data organized ion columns

# %% [markdown]
# # <center>ARRAYS OF DATA</center>

# %% [markdown]
# Lists are very flexible, but can also use a lot of memory, and even have alower performance
#
# To fix this we have the array - arrays structure other objects of the same data type in rows and columns

# %% [markdown]
# If we think only of numbers,
#
# A 1-dimensional array is a vector of real numbers (single row or column of elements only)
#
# In more common cases, the 2-dimensional array represents an i x j matrix of elements
#
# This concept generalizes to i x j x k cubes of elements in 3 dimensions
#
# As well as to general n-dimensional arrays of shape i x j x k x l x ...

# %% [markdown]
# It is useful to have a specialized class of data structures explicitly desgined to handle arrays conveniently and efficiently.
#
# This is where the NumPy library comes into play, with its powerful ndarray class

# %% [markdown]
# But first, we introduce 2 alternatives for the handling of arrays

# %% [markdown]
# # <center>ARRAYS WITH PYTHON LISTS</center>

# %% [markdown]
# Arrays can be constructed with the built-in data structures presented in the previous chapter.
#
# A simple list can be considered a 1-dimensional array

# %%
v=[0.5, 1.5, 2.5, 2.0]

# %% [markdown]
# Higher-dimensional arrays can eaily be constructed by nesting lists

# %%
m=[v, v, v] 
m
# Out:
# [[0.5, 1.5, 2.5, 2.0], [0.5, 1.5, 2.5, 2.0], [0.5, 1.5, 2.5, 2.0]]

# %%
v1 = [0.5, 1.5]
v2 = [1, 2]
m = [v1, v2]
c = [m, m] 
c
# Out:
# [[[0.5, 1.5], [1, 2]], [[0.5, 1.5], [1, 2]]]

# %%
 c[1][1][0]
# Out:
# 1

# %% [markdown]
# Note that combining objects in this way generally works with reference pointers to original objects

# %%
v = [0.5, 0.75, 1.0, 1.5, 2.0]
m = [v, v, v]
m
# Out:
# [[0.5, 0.75, 1.0, 1.5, 2.0],
#  [0.5, 0.75, 1.0, 1.5, 2.0],
#  [0.5, 0.75, 1.0, 1.5, 2.0]]

# %%
v[0]='Changed'
m
# Out:
# [['Changed', 0.75, 1.0, 1.5, 2.0],
#  ['Changed', 0.75, 1.0, 1.5, 2.0],
#  ['Changed', 0.75, 1.0, 1.5, 2.0]]

# %% [markdown]
# This can be avoided by using the deppcopy() function of the copy module

# %%
import copy
v = [0.5, 0.75, 1.0, 1.5, 2.0]
m=3*[copy.deepcopy(v)]
m
# Out:
# [[0.5, 0.75, 1.0, 1.5, 2.0],
#  [0.5, 0.75, 1.0, 1.5, 2.0],
#  [0.5, 0.75, 1.0, 1.5, 2.0]]

# %%
v[0]='Changed'
m
# Out:
# [[0.5, 0.75, 1.0, 1.5, 2.0],
#  [0.5, 0.75, 1.0, 1.5, 2.0],
#  [0.5, 0.75, 1.0, 1.5, 2.0]]

# %% [markdown]
# # <center>THE PYTHON ARRAY CLASS </center>

# %% [markdown]
# There is a dedicated array module in python
#
# This module defines an object type which can compactly represent an array of basic
# values: characters, integers, floating point numbers. Arrays are sequence types and
# behave very much like lists, except that the type of objects stored in them is con‐
# strained. The type is specified at object creation time by using a type code, which is a
# single character.

# %%
v = [0.5, 0.75, 1.0, 1.5, 2.0]

import array

a=array.array('f', v)
a
# Out:
# array('f', [0.5, 0.75, 1.0, 1.5, 2.0])

# %%
a.append(0.5)
a
# Out:
# array('f', [0.5, 0.75, 1.0, 1.5, 2.0, 0.5])

# %%
a.extend([5.0, 6.75])
a
# Out:
# array('f', [0.5, 0.75, 1.0, 1.5, 2.0, 0.5, 5.0, 6.75])

# %%
2*a
# Out:
# array('f', [0.5, 0.75, 1.0, 1.5, 2.0, 0.5, 5.0, 6.75, 0.5, 0.75, 1.0, 1.5, 2.0, 0.5, 5.0, 6.75])
